</td><td>1N62wozuHCvczCkY4Qidp</td><td>Over My Head (Cable Car)</td><td>The Fray</td><td>0.592</td><td>0.729</td><td>8</td><td>-4.156</td><td>1</td><td>0.0448</td><td>0.022</td><td>0.0</td><td>0.0653</td><td>0.709</td><td>116.03</td><td>236267</td><td>4</td></tr><tr><td>2006</td><td>5xoUgPXbMNUmoHU0Enwtw</td><td>She Moves In Her Own Way</td><td>The Kooks</td><td>0.41</td><td>0.803</td><td>7</td><td>-5.363</td><td>1</td><td>0.0623</td><td>0.239</td><td>0.0</td><td>0.103</td><td>0.814</td><td>153.315</td><td>169307</td><td>4</td></tr><tr><td>2006</td><td>6bFsQ6yOp3z5mGNkhWP0P</td><td>You Give Me Something</td><td>James Morrison</td><td>0.559</td><td>0.688</td><td>7</td><td>-6.496</td><td>1</td><td>0.114</td><td>0.216</td><td>0.0</td><td>0.0855</td><td>0.578</td><td>79.753</td><td>213173</td><td>4</td></tr><tr><td>2006</td><td>6yLX8QnxlnEqZfs3YKCfj</td><td>Tears Dry On Their Own</td><td>Amy Winehouse</td><td>0.643</td><td>0.871</td><td>1</td><td>-2.734</td><td>0</td><td>0.118</td><td>0.491</td><td>0.0</td><td>0.29</td><td>0.452</td><td>121.569</td><td>185187</td><td>4</td></tr><tr><td>2006</td><td>19iqWNzp5LwEdvntpEK8M</td><td>Steady, As She Goes</td><td>The Raconteurs</td><td>0.524</td><td>0.578</td><td>9</td><td>-4.563</td><td>1</td><td>0.12</td><td>0.0132</td><td>0.00921</td><td>0.108</td><td>0.537</td><td>123.669</td><td>215267</td><td>4</td></tr><tr><td>2006</td><td> ...

# %%
# %sql
CREATE OR REPLACE STREAMING LIVE TABLE silver_table
  COMMENT 'Transformed data from bronze with unnecessary columns removed'
  AS
  SELECT 
    year,
    id,
    name,
    artists,
    danceability,
    energy,
    key,
    loudness,
    speechiness,
    acousticness,
    instrumentalness,
    liveness,
    valence,
    tempo,
    duration_ms
  FROM spoty.spoty_schema.bronze_table
# Out:
# <html>
#   <style>
# <style>
#       html {
#         font-family: -apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,
#         Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,
#         Noto Color Emoji,FontAwesome;
#         font-size: 13;
#       }
#
#       .ansiout {
#         padding-bottom: 8px;
#       }
#
#       .createPipeline {
#         background-color: rgb(34, 114, 180);
#         color: white;
#         text-decoration: none;
#         padding: 4px 12px;
#         border-radius: 4px;
#         display: inline-block;
#       }
#
#       .createPipeline:hover {
#         background-color: #195487;
#       }
#
#       .tag {
#         border: none;
#         color: rgb(31, 39, 45);
#         padding: 2px 4px;
#         font-weight: 600;
#         background-color: rgba(93, 114, 131, 0.08);
#         border-radius: 4px;
#         margin-right: 0;
#         display: inline-block;
#         cursor: default;
#       }
#
#       table {
#         border-collapse: collapse;
#         font-size: 13px;
#       }
#
#       th {
#         text-align: left;
#         background-color: #F2F5F7;
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       tr {
#         border-bottom: solid;
#         border-bottom-color: #CDDAE5;
#         border-bottom-width: 1px;
#       }
#
#       td {
#         padding-left: 8px;
#         padding-right: 8px;
#       }
#
#       .dlt-label {
#         font-weight: bold;
#       }
#
#       ul {
#         list-style: circle;
#         padding-inline-start: 12px;
#       }
#
#       li {
#         padding-bottom: 4px;
#       }
# </style></style>
#
# <div class="ansiout">
# <span class='tag'>silver_table</span> is defined as a
# <span class="dlt-label">Delta Live Tables</span> dataset
#  with schema:
# </div>
#
#
# <div class="ansiout">
#    <table>
#      <tbody>
#        <tr>
#          <th>Name</th>
#          <th>Type</th>
#        </tr>
#
# <tr>
#    <td>year</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>id</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>name</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>artists</td>
#    <td>string</td>
# </tr>
#
# <tr>
#    <td>danceability</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>energy</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>key</td>
#    <td>int</td>
# </tr>
#
# <tr>
#    <td>loudness</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>speechiness</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>acousticness</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>instrumentalness</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>liveness</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>valence</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>tempo</td>
#    <td>double</td>
# </tr>
#
# <tr>
#    <td>duration_ms</td>
#    <td>int</td>
# </tr>
#      </tbody>
#    </table>
# </div>
#
#   <div class ="ansiout">
#     To populate your table you must either:
#     <ul>
#       <li>
#         Run an existing pipeline using the
#         <span class="dlt-label">Delta Live Tables</span> menu
#       </li>
#       <li>
#         Create a new pipeline: <a class='createPipeline' href="?o=377448649117497#joblist/pipelines/create?initialSource=%2FUsers%2Fynwa_07%40hotmail.com%2FSpoty%2FSpotify%20-%20silver&redirectNotebookId=557003795110867">Create Pipeline</a>
#       </li>
#     </ul>
#   <div>
# </html>

# %%
# Read the bronze table into a DataFrame
bronze_df = spark.table("spoty.spoty_schema.bronze_table")

# Select the columns you want to keep (excluding 'mode' and 'time_signature')
silver_df = bronze_df.select(
    "year",
    "id",
    "name",
    "artists",
    "danceability",
    "energy",
    "key",
    "loudness",
    "speechiness",
    "acousticness",
    "instrumentalness",
    "liveness",
    "valence",
    "tempo",
    "duration_ms"
)

# Write the result to the silver table
silver_df.write.format("delta").mode("overwrite").saveAsTable("spoty.spoty_schema.silver_table")

# %%
# %sql
SELECT * FROM spoty.spoty_schema.silver_table
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>year</th><th